# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sample_csv = "FoodBalanceSheets_E_Africa_NOFLAG.csv"
food_data = pd.read_csv(sample_csv, encoding="latin-1")
# checking if the data was properly downloaded
food_data.describe(include="all")
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
# total sum of wine produced in 2015 and 2018
food_data.groupby('Item').sum()
# Out:
#                           Area Code  Item Code  Element Code      Y2014  \
# Item
# Alcohol, Non-Food             38447     752497       1515090    2403.00
# Alcoholic Beverages           75016    1649136       2171381  102410.11
# Animal Products               18060     397035         90990   11935.65
# Animal fats                   85279    1882494       2567303  209460.54
# Apples and products           69280    1352989       1920418    9499.23
# Aquatic Animals, Others       47420     966381       1139179      14.55
# Aquatic Plants                51178    1057275       1278386     507.29
# Aquatic Products, Other       52570    1160712       1320249     519.62
# Bananas                       68496    1338880       1894890   53267.31
# Barley and products           76321    1432410       2243002   25384.66
# Beans                         78001    1476680       2263509   19207.68
# Beer                          65975    1314720       1813728   41879.92
# ...

# %%
# areas with the highest sum in 2017
food_data.groupby('Area')['Y2017'].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
# checking error for output of following code: Question 4
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-027147966a3a> in <module>
#       1 # checking error for output of following code: Question 4
#       2 my_tuppy = (1,2,5,8)
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
food_data.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
# getting the measures of central tendency from the dataset
food_data.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
# question 7
y = [(2,4),(7,8),(1,5,9)]
x = y[1][1]
x
# Out:
# 8

# %%
# question 7: second possible solution
w = y[1][-1]
w
# Out:
# 8

# %%
# total number of missing data in 2014
food_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# percentage of missing data in 2014
y_2014_per = (1589/60943) * 100 # 60943 is the total number of rows in the dataset
print(y_2014_per)
# Out:
# 2.6073544131401474

# %%
# question 10
food_data.groupby('Area', sort=True)['Y2017'].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
# produced error as I wasn't able to get this
food_data.groupby('Area','Madagascar')['Y2015'].sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-2ade76a71892> in <module>
#       1 # produced error as I wasn't able to get this
# ----> 2 food_data.groupby('Area','Madagascar')['Y2015'].sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6660         if level is None and by is None:
#    6661             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 6662         axis = self._get_axis_number(axis)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     373                 pass
# ...

# %%
#finding number of distinct areas in the dataset
food_data.drop_duplicates('Area').count()
# Out:
# Area Code       49
# Area            49
# Item Code       49
# Item            49
# Element Code    49
# Element         49
# Unit            49
# Y2014           49
# Y2015           49
# Y2016           49
# Y2017           49
# Y2018           49
# dtype: int64

# %%
food_data.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
# the stock variation question
food_data.groupby('Element')['Area'].count()
# Out:
# Element
# Domestic supply quantity                  5295
# Export Quantity                           4403
# Fat supply quantity (g/capita/day)        5023
# Feed                                      1319
# Food                                      4941
# Food supply (kcal/capita/day)             5014
# Food supply quantity (kg/capita/yr)       4905
# Import Quantity                           5139
# Losses                                    2009
# Other uses (non-food)                     1732
# Processing                                2010
# Production                                3881
# Protein supply quantity (g/capita/day)    5023
# Residuals                                 4655
# Seed                                       762
# Stock Variation                           4232
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Area, dtype: int64
